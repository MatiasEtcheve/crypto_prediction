# %%
import sys
from pathlib import Path

IS_COLAB = "google.colab" in sys.modules
IS_KAGGLE = "kaggle_secrets" in sys.modules
if IS_KAGGLE:
    repo_path = Path("../input/crypto-prediction")
elif IS_COLAB:
    from google.colab import drive

    drive.mount("/content/gdrive")
    repo_path = Path("/content/gdrive/MyDrive/crypto-prediction")
else:
    repo_path = Path("/home/matias/crypto-prediction")
sys.path.append(str(repo_path))

import asyncio
import os
import pickle
import re
import sys
import time
from dataclasses import dataclass
from datetime import datetime, timedelta
from importlib import reload
from pathlib import Path
from pprint import pprint
from typing import Callable, List, Optional, Union

import ccxt
import get_data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pytz
import talib
import tensorflow as tf
import wandb
import yfinance as yf
from binance import AsyncClient, BinanceSocketManager
from binance.client import Client
from binance.enums import *
from binance.exceptions import BinanceAPIException
from binance.helpers import round_step_size
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from tensorflow.keras import layers
from tensorflow.keras.activations import sigmoid, tanh
from tensorflow.keras.models import Model
from tools import inspect_code, plotting, training, wandb_api
from tools.training import Datapoint
from tqdm import tqdm
from wandb.keras import WandbCallback
from portfolio import portfolio

log_wandb = True
tf.config.list_physical_devices("CPU")[0].device_type
starting_date = datetime.now()
# Out:
# 2022-04-11 22:46:33.632919: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-11 22:46:33.632975: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-04-11 22:46:36.026158: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-04-11 22:46:36.026199: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-11 22:46:36.026215: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Matias): /proc/driver/nvidia/version does not exist

# %%
wandb_api.login()
api = wandb.Api()
run_name = "1fullt5y"
run = api.run(f"matiasetcheverry/crypto-prediction/{run_name}")
config = run.config

root_path = Path("tmp")
datamodule_script = run.file("datamodule_script.txt")
datamodule_script = datamodule_script.download(root=root_path / run.name, replace=True)
datamodule_script.seek(0)
datamodule_name = re.findall(r"(?<=class ).[a-zA-Z0-9_.-]*", datamodule_script.read())[
    0
]
datamodule_script.seek(0)

with open(datamodule_script.name, "r") as file:
    exec(file.read())

model = run.file("rf.pkl")
model = model.download(root=root_path / run.name, replace=True)
with open(model.name, "rb") as file:
    rf = pickle.load(file)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: matiasetcheverry (use `wandb login --relogin` to force relogin)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/matias/.netrc

# %%
class ClassificationPortfolio(portfolio.Portfolio):
    def compute_amount_money(
        self, money: float, directions: np.ndarray, probabilities: np.ndarray
    ):
        # preallocated_money = [
        #     float(self.client.get_asset_balance(asset=asset.ticker)["free"])
        #     - asset.initial_amount
        #     for asset in self.assets.values()
        # ]
        allocated_money = np.zeros_like(probabilities)
        # mask = directions * (np.array(preallocated_money) == 0)
        mask = directions
        allocated_money[mask] = (
            probabilities[mask] * money / np.sum(probabilities[mask])
        )
        return allocated_money

    def compute_probabilities(self) -> np.ndarray:
        probabilities = []
        for asset in self.assets.values():
            try:
                probabilities.append(asset.predict_proba_last_from(rf))
            except ValueError as e:
                print(f"Problem predicting on {asset.ticker}")
                print(f"\t{e}")
                probabilities.append(0)
        return np.array(probabilities)


    def trade(self, money: int):
        self.cancel_orders()
        probabilities = self.compute_probabilities()
        directions = probabilities > 0.5
        allocated_money = self.compute_amount_money(
            money,
            directions,
            probabilities,
        )
        order_ids = []
        for index, asset in enumerate(self.assets.values()):
            probability = probabilities[index]
            direction = directions[index]
            money = allocated_money[index]
            orders = self.swap_single_ticker(direction, money, asset)
            if orders is not None:
                for order in orders:
                    print("New order")
                    print(f"\tTICKER: {order['symbol']}")
                    print(f"\tSide: {order['side']}")
                    print(f"\tProba going up: {probability}")
                    print(f"\tAmount: {order['origQty']}")
                    print(f"\tPrice: {order['price']}")
                    print(
                        f"\tMoney allocated: {float(order['origQty'])*float(order['price'])}"
                    )
                    print(f"\tOrder id: {order['orderId']}")
                    print(f"\tTransaction time: {order['transactTime']}")
                    order_ids.append(
                        {"symbol": order["symbol"], "orderId": order["orderId"]}
                    )
        return order_ids

# reload(portfolio)
# key = "aqyuK7BLhzYiU2SCeALa7wayggR9769RtVenBI57683r7N2YC6bT3KUBwSw9zsGk"
# secret = "XqhAXqp6J7OsgRX40T7NH2iHjFpSegtImWcOAwEwuNWcdQKo4GMrzpGu9tUxQe97"
# client = Client(key, secret, testnet=True)
api_key = os.environ.get("TESTNET_API")
api_secret = os.environ.get("TESTNET_SECRET")
client = Client(api_key, api_secret, testnet=True)
pf = ClassificationPortfolio(client, config, repo_path / "live_trading", ["BNB", "BTC", "ETH", "LTC", "TRX", "XRP"])
# pf.trade(float(pf.client.get_asset_balance(asset="BUSD")["free"]))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
async def kline_listener(aclient):
    bm = BinanceSocketManager(aclient)
    input_coroutines = [
        asset.kline_listener(bm, interval="5m") for asset in list(pf.assets.values())
    ]
    await asyncio.gather(*input_coroutines, return_exceptions=True)
    print("Finally gathered at:", datetime.now())
    # assert all(
    #     list(dm.datapoints.values())[0].df.shape == dp.df.shape
    #     for dp in dm.datapoints.values()
    # )
    print("Initially traded at:", datetime.now())
    pf.trade(float(pf.client.get_asset_balance(asset="BUSD")["free"]))
    print("Finally traded at:", datetime.now())

    for asset in pf.assets.values():
        asset.update_trades(client, starting_date=starting_date, limit=20)
        asset.update_orders(client, starting_date=starting_date, limit=20)
        asset.save_history(repo_path / "live_trading" / asset.ticker)
    pf.save_balances(repo_path / "live_trading" / "balances.csv")


aclient = await AsyncClient.create()
while True:
    await kline_listener(aclient)
    print("------------------------------------------")
# Out:
# Finally gathered at: 2022-04-12 00:00:08.574788
# Initially traded at: 2022-04-12 00:00:08.575027
# New order
# 	TICKER: BNBBUSD
# 	Side: SELL
# 	Proba going up: 0.44563736888217437
# 	Amount: 46.45000000
# 	Price: 392.90000000
# 	Money allocated: 18250.205
# 	Order id: 404905
# 	Transaction time: 1649714418715
# New order
# 	TICKER: BTCBUSD
# 	Side: SELL
# 	Proba going up: 0.4711701501258713
# 	Amount: 1.58002400
# 	Price: 39398.86000000
# 	Money allocated: 62251.14437264
# 	Order id: 1805150
# 	Transaction time: 1649714422060
# New order
# 	TICKER: LTCBUSD
# 	Side: SELL
# 	Proba going up: 0.4462977227195228
# 	Amount: 269.99137000
# 	Price: 102.70000000
# 	Money allocated: 27728.113699
# 	Order id: 53944
# 	Transaction time: 1649714424029
# New order
# 	TICKER: XRPBUSD
# 	Side: SELL
# 	Proba going up: 0.4357070865005683
# 	Amount: 45505.60000000
# 	Price: 0.68580000
# 	Money allocated: 31207.740479999997
# 	Order id: 419152
# 	Transaction time: 1649714425328
# Finally traded at: 2022-04-12 00:00:25.933017
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:05:08.818783
# Initially traded at: 2022-04-12 00:05:08.819079
# New order
# 	TICKER: BNBBUSD
# 	Side: BUY
# 	Proba going up: 0.5056298675833626
# 	Amount: 63.56000000
# 	Price: 393.10000000
# 	Money allocated: 24985.436
# 	Order id: 405316
# 	Transaction time: 1649714721985
# New order
# 	TICKER: BTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5244409992757095
# 	Amount: 0.65768900
# 	Price: 39405.68000000
# 	Money allocated: 25916.68227352
# 	Order id: 1806402
# 	Transaction time: 1649714723914
# New order
# 	TICKER: ETHBUSD
# 	Side: BUY
# 	Proba going up: 0.5291986691699427
# 	Amount: 8.80651000
# 	Price: 2969.60000000
# 	Money allocated: 26151.812095999998
# 	Order id: 1778336
# 	Transaction time: 1649714726279
# New order
# 	TICKER: LTCBUSD
# 	Side: SELL
# 	Proba going up: 0.49889266615729977
# 	Amount: 152.25672000
# 	Price: 102.90000000
# 	Money allocated: 15667.216488000002
# 	Order id: 54022
# 	Transaction time: 1649714727412
# New order
# 	TICKER: TRXBUSD
# 	Side: BUY
# 	Proba going up: 0.528817712678636
# 	Amount: 90000.00000000
# 	Price: 0.05801000
# 	Money allocated: 5220.9
# 	Order id: 332599
# 	Transaction time: 1649714728212
# New order
# 	TICKER: XRPBUSD
# 	Side: BUY
# 	Proba going up: 0.5278706176826479
# 	Amount: 37943.50000000
# 	Price: 0.68750000
# 	Money allocated: 26086.15625
# 	Order id: 420045
# 	Transaction time: 1649714728989
# Finally traded at: 2022-04-12 00:05:29.604117
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:10:08.467826
# Initially traded at: 2022-04-12 00:10:08.468028
# New order
# 	TICKER: BNBBUSD
# 	Side: BUY
# 	Proba going up: 0.5442403775670251
# 	Amount: 9.94000000
# 	Price: 392.60000000
# 	Money allocated: 3902.444
# 	Order id: 405714
# 	Transaction time: 1649715015439
# New order
# 	TICKER: BTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5381635086598409
# 	Amount: 0.09805000
# 	Price: 39363.29000000
# 	Money allocated: 3859.5705845
# 	Order id: 1807598
# 	Transaction time: 1649715016219
# New order
# 	TICKER: ETHBUSD
# 	Side: BUY
# 	Proba going up: 0.5624821795133337
# 	Amount: 1.36144000
# 	Price: 2963.04000000
# 	Money allocated: 4034.0011776
# 	Order id: 1779531
# 	Transaction time: 1649715017668
# New order
# 	TICKER: LTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5165898608982011
# 	Amount: 36.03963000
# 	Price: 102.80000000
# 	Money allocated: 3704.8739640000003
# 	Order id: 54082
# 	Transaction time: 1649715018444
# New order
# 	TICKER: TRXBUSD
# 	Side: BUY
# 	Proba going up: 0.5508951941694632
# 	Amount: 68166.00000000
# 	Price: 0.05796000
# 	Money allocated: 3950.90136
# 	Order id: 333015
# 	Transaction time: 1649715019228
# New order
# 	TICKER: XRPBUSD
# 	Side: BUY
# 	Proba going up: 0.522967420134612
# 	Amount: 5475.30000000
# 	Price: 0.68500000
# 	Money allocated: 3750.5805000000005
# 	Order id: 420663
# 	Transaction time: 1649715020059
# Finally traded at: 2022-04-12 00:10:20.726611
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:15:05.060962
# Initially traded at: 2022-04-12 00:15:05.061184
# New order
# 	TICKER: BNBBUSD
# 	Side: SELL
# 	Proba going up: 0.49958973919284044
# 	Amount: 73.50000000
# 	Price: 393.40000000
# 	Money allocated: 28914.899999999998
# 	Order id: 406432
# 	Transaction time: 1649715312130
# Can't buy BTC dust:
# Can't buy ETH dust:
# Can't buy LTC dust:
# Can't buy TRX dust:
# Can't buy XRP dust:
# Finally traded at: 2022-04-12 00:15:16.685354
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:20:08.452770
# Initially traded at: 2022-04-12 00:20:08.453513
# New order
# 	TICKER: BNBBUSD
# 	Side: BUY
# 	Proba going up: 0.5329793888387098
# 	Amount: 12.07000000
# 	Price: 395.40000000
# 	Money allocated: 4772.478
# 	Order id: 406983
# 	Transaction time: 1649715615222
# New order
# 	TICKER: BTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5501276315076361
# 	Amount: 0.12399400
# 	Price: 39755.07000000
# 	Money allocated: 4929.39014958
# 	Order id: 1810051
# 	Transaction time: 1649715617124
# New order
# 	TICKER: ETHBUSD
# 	Side: BUY
# 	Proba going up: 0.5515688834136343
# 	Amount: 1.65194000
# 	Price: 2991.83000000
# 	Money allocated: 4942.3236502
# 	Order id: 1781987
# 	Transaction time: 1649715618584
# New order
# 	TICKER: LTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5477866542164022
# 	Amount: 47.33301000
# 	Price: 103.70000000
# 	Money allocated: 4908.433137
# 	Order id: 54257
# 	Transaction time: 1649715619447
# New order
# 	TICKER: TRXBUSD
# 	Side: BUY
# 	Proba going up: 0.5198426629217018
# 	Amount: 79843.00000000
# 	Price: 0.05834000
# 	Money allocated: 4658.040620000001
# 	Order id: 334047
# 	Transaction time: 1649715620252
# New order
# 	TICKER: XRPBUSD
# 	Side: BUY
# 	Proba going up: 0.5251005262082376
# 	Amount: 6790.50000000
# 	Price: 0.69290000
# 	Money allocated: 4705.13745
# 	Order id: 422171
# 	Transaction time: 1649715621145
# Finally traded at: 2022-04-12 00:20:21.787428
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:25:05.270730
# Initially traded at: 2022-04-12 00:25:05.270992
# New order
# 	TICKER: BNBBUSD
# 	Side: SELL
# 	Proba going up: 0.49069059859299463
# 	Amount: 12.07000000
# 	Price: 395.90000000
# 	Money allocated: 4778.513
# 	Order id: 407342
# 	Transaction time: 1649715913611
# New order
# 	TICKER: BTCBUSD
# 	Side: SELL
# 	Proba going up: 0.4809913819368473
# 	Amount: 0.87973300
# 	Price: 39790.25000000
# 	Money allocated: 35004.79600325
# 	Order id: 1811273
# 	Transaction time: 1649715915194
# New order
# 	TICKER: ETHBUSD
# 	Side: SELL
# 	Proba going up: 0.473570536597708
# 	Amount: 11.81989000
# 	Price: 2994.38000000
# 	Money allocated: 35393.2422182
# 	Order id: 1783204
# 	Transaction time: 1649715916248
# New order
# 	TICKER: LTCBUSD
# 	Side: SELL
# 	Proba going up: 0.49582124114315257
# 	Amount: 219.56684000
# 	Price: 103.80000000
# 	Money allocated: 22791.037992
# 	Order id: 54294
# 	Transaction time: 1649715917323
# New order
# 	TICKER: TRXBUSD
# 	Side: SELL
# 	Proba going up: 0.4785791734011368
# 	Amount: 90000.00000000
# 	Price: 0.05849000
# 	Money allocated: 5264.1
# 	Order id: 334398
# 	Transaction time: 1649715918470
# New order
# 	TICKER: TRXBUSD
# 	Side: SELL
# 	Proba going up: 0.4785791734011368
# 	Amount: 90000.00000000
# 	Price: 0.05849000
# 	Money allocated: 5264.1
# 	Order id: 334399
# 	Transaction time: 1649715919279
# New order
# 	TICKER: TRXBUSD
# 	Side: SELL
# 	Proba going up: 0.4785791734011368
# 	Amount: 58009.00000000
# 	Price: 0.05849000
# 	Money allocated: 3392.94641
# 	Order id: 334405
# 	Transaction time: 1649715920158
# New order
# 	TICKER: XRPBUSD
# 	Side: SELL
# 	Proba going up: 0.459804066483077
# 	Amount: 50209.30000000
# 	Price: 0.69360000
# 	Money allocated: 34825.17048
# 	Order id: 422803
# 	Transaction time: 1649715921195
# Finally traded at: 2022-04-12 00:25:21.901384
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:30:08.681405
# Initially traded at: 2022-04-12 00:30:08.681585
# New order
# 	TICKER: BNBBUSD
# 	Side: BUY
# 	Proba going up: 0.5099785619248475
# 	Amount: 165.28000000
# 	Price: 395.90000000
# 	Money allocated: 65434.352
# 	Order id: 407622
# 	Transaction time: 1649716215324
# New order
# 	TICKER: BTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5081229302544099
# 	Amount: 1.63767500
# 	Price: 39811.76000000
# 	Money allocated: 65198.724058
# 	Order id: 1812508
# 	Transaction time: 1649716217463
# New order
# 	TICKER: LTCBUSD
# 	Side: SELL
# 	Proba going up: 0.48154266007103697
# 	Amount: 155.30859000
# 	Price: 103.90000000
# 	Money allocated: 16136.562501000002
# 	Order id: 54327
# 	Transaction time: 1649716218741
# Finally traded at: 2022-04-12 00:30:19.995475
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:35:07.624870
# Initially traded at: 2022-04-12 00:35:07.625062
# New order
# 	TICKER: BNBBUSD
# 	Side: BUY
# 	Proba going up: 0.5338331137447895
# 	Amount: 2.25000000
# 	Price: 397.00000000
# 	Money allocated: 893.25
# 	Order id: 407979
# 	Transaction time: 1649716516854
# New order
# 	TICKER: BTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5377392786438089
# 	Amount: 0.02261500
# 	Price: 39896.64000000
# 	Money allocated: 902.2625135999999
# 	Order id: 1813726
# 	Transaction time: 1649716518995
# New order
# 	TICKER: ETHBUSD
# 	Side: BUY
# 	Proba going up: 0.5272547893445247
# 	Amount: 0.29412000
# 	Price: 3007.89000000
# 	Money allocated: 884.6806068
# 	Order id: 1785639
# 	Transaction time: 1649716519773
# New order
# 	TICKER: LTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5071782210357382
# 	Amount: 8.19078000
# 	Price: 103.90000000
# 	Money allocated: 851.022042
# 	Order id: 54363
# 	Transaction time: 1649716520581
# New order
# 	TICKER: TRXBUSD
# 	Side: BUY
# 	Proba going up: 0.516012958480072
# 	Amount: 14762.90000000
# 	Price: 0.05865000
# 	Money allocated: 865.844085
# 	Order id: 335113
# 	Transaction time: 1649716521372
# New order
# 	TICKER: XRPBUSD
# 	Side: BUY
# 	Proba going up: 0.5261689775647739
# 	Amount: 1267.60000000
# 	Price: 0.69650000
# 	Money allocated: 882.8833999999999
# 	Order id: 423861
# 	Transaction time: 1649716522154
# Finally traded at: 2022-04-12 00:35:22.823092
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:40:08.532558
# Initially traded at: 2022-04-12 00:40:08.533212
# New order
# 	TICKER: BNBBUSD
# 	Side: BUY
# 	Proba going up: 0.5138672509490344
# 	Amount: 47.25000000
# 	Price: 397.90000000
# 	Money allocated: 18800.774999999998
# 	Order id: 408346
# 	Transaction time: 1649716816876
# New order
# 	TICKER: BTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5197715059049133
# 	Amount: 0.47576000
# 	Price: 39978.42000000
# 	Money allocated: 19020.1330992
# 	Order id: 1814916
# 	Transaction time: 1649716819032
# New order
# 	TICKER: ETHBUSD
# 	Side: BUY
# 	Proba going up: 0.5359595394449105
# 	Amount: 6.51145000
# 	Price: 3012.00000000
# 	Money allocated: 19612.487399999998
# 	Order id: 1786830
# 	Transaction time: 1649716819813
# New order
# 	TICKER: LTCBUSD
# 	Side: SELL
# 	Proba going up: 0.4948349900360244
# 	Amount: 104.49047000
# 	Price: 104.10000000
# 	Money allocated: 10877.457927
# 	Order id: 54386
# 	Transaction time: 1649716820812
# New order
# 	TICKER: TRXBUSD
# 	Side: BUY
# 	Proba going up: 0.5022254219440805
# 	Amount: 90000.00000000
# 	Price: 0.05870000
# 	Money allocated: 5283.0
# 	Order id: 335349
# 	Transaction time: 1649716821593
# New order
# 	TICKER: XRPBUSD
# 	Side: BUY
# 	Proba going up: 0.5034795686545522
# 	Amount: 26346.20000000
# 	Price: 0.69930000
# 	Money allocated: 18423.897660000002
# 	Order id: 424298
# 	Transaction time: 1649716822414
# Finally traded at: 2022-04-12 00:40:23.094850
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:45:06.112851
# Initially traded at: 2022-04-12 00:45:06.113005
# New order
# 	TICKER: BNBBUSD
# 	Side: SELL
# 	Proba going up: 0.44855914473455005
# 	Amount: 62.60000000
# 	Price: 397.60000000
# 	Money allocated: 24889.760000000002
# 	Order id: 408638
# 	Transaction time: 1649717114506
# New order
# 	TICKER: BTCBUSD
# 	Side: SELL
# 	Proba going up: 0.4584460569391825
# 	Amount: 1.28241000
# 	Price: 39936.82000000
# 	Money allocated: 51215.3773362
# 	Order id: 1816106
# 	Transaction time: 1649717116879
# New order
# 	TICKER: ETHBUSD
# 	Side: SELL
# 	Proba going up: 0.4742441081080766
# 	Amount: 6.80557000
# 	Price: 3011.00000000
# 	Money allocated: 20491.57127
# 	Order id: 1788005
# 	Transaction time: 1649717117907
# New order
# 	TICKER: LTCBUSD
# 	Side: SELL
# 	Proba going up: 0.4391492178522561
# 	Amount: 96.51737000
# 	Price: 104.00000000
# 	Money allocated: 10037.80648
# 	Order id: 54421
# 	Transaction time: 1649717119038
# New order
# 	TICKER: TRXBUSD
# 	Side: SELL
# 	Proba going up: 0.45263120517140043
# 	Amount: 90000.00000000
# 	Price: 0.05861000
# 	Money allocated: 5274.900000000001
# 	Order id: 335641
# 	Transaction time: 1649717120163
# New order
# 	TICKER: TRXBUSD
# 	Side: SELL
# 	Proba going up: 0.45263120517140043
# 	Amount: 14762.80000000
# 	Price: 0.05861000
# 	Money allocated: 865.247708
# 	Order id: 335643
# 	Transaction time: 1649717120961
# New order
# 	TICKER: XRPBUSD
# 	Side: SELL
# 	Proba going up: 0.47157833635752816
# 	Amount: 26346.20000000
# 	Price: 0.70040000
# 	Money allocated: 18452.87848
# 	Order id: 424950
# 	Transaction time: 1649717121950
# Finally traded at: 2022-04-12 00:45:22.638062
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:50:08.735563
# Initially traded at: 2022-04-12 00:50:08.735811
# New order
# 	TICKER: BNBBUSD
# 	Side: BUY
# 	Proba going up: 0.5266425894399839
# 	Amount: 8.83000000
# 	Price: 396.20000000
# 	Money allocated: 3498.446
# 	Order id: 409001
# 	Transaction time: 1649717417668
# New order
# 	TICKER: BTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5412735647944287
# 	Amount: 0.09051300
# 	Price: 39763.37000000
# 	Money allocated: 3599.10190881
# 	Order id: 1817318
# 	Transaction time: 1649717418448
# New order
# 	TICKER: ETHBUSD
# 	Side: BUY
# 	Proba going up: 0.5455685510677323
# 	Amount: 1.21013000
# 	Price: 2997.74000000
# 	Money allocated: 3627.6551061999994
# 	Order id: 1789207
# 	Transaction time: 1649717419275
# New order
# 	TICKER: LTCBUSD
# 	Side: BUY
# 	Proba going up: 0.5175982243325558
# 	Amount: 33.25306000
# 	Price: 103.50000000
# 	Money allocated: 3441.6917099999996
# 	Order id: 54488
# 	Transaction time: 1649717420044
# New order
# 	TICKER: TRXBUSD
# 	Side: BUY
# 	Proba going up: 0.5245810263551455
# 	Amount: 59738.30000000
# 	Price: 0.05839000
# 	Money allocated: 3488.119337
# 	Order id: 336064
# 	Transaction time: 1649717420848
# New order
# 	TICKER: XRPBUSD
# 	Side: BUY
# 	Proba going up: 0.5187758465417359
# 	Amount: 4938.40000000
# 	Price: 0.69850000
# 	Money allocated: 3449.4723999999997
# 	Order id: 425607
# 	Transaction time: 1649717421635
# Finally traded at: 2022-04-12 00:50:22.347139
# ------------------------------------------
# Finally gathered at: 2022-04-12 00:55:08.564569
# Initially traded at: 2022-04-12 00:55:08.564749
# Can't buy BNB dust:
# Can't buy BTC dust:
# Can't buy ETH dust:
# New order
# 	TICKER: LTCBUSD
# 	Side: SELL
# 	Proba going up: 0.48288859427020386
# 	Amount: 112.55603000
# 	Price: 103.70000000
# 	Money allocated: 11672.060311000001
# 	Order id: 54511
# 	Transaction time: 1649717718751
# New order
# 	TICKER: TRXBUSD
# 	Side: SELL
# 	Proba going up: 0.4793069665884512
# 	Amount: 90000.00000000
# 	Price: 0.05857000
# 	Money allocated: 5271.3
# 	Order id: 336423
# 	Transaction time: 1649717719849
# New order
# 	TICKER: TRXBUSD
# 	Side: SELL
# 	Proba going up: 0.4793069665884512
# 	Amount: 56552.70000000
# 	Price: 0.05857000
# 	Money allocated: 3312.2916389999996
# 	Order id: 336424
# 	Transaction time: 1649717720584
# New order
# 	TICKER: XRPBUSD
# 	Side: SELL
# 	Proba going up: 0.4973759531049511
# 	Amount: 29842.80000000
# 	Price: 0.70240000
# 	Money allocated: 20961.58272
# 	Order id: 426094
# 	Transaction time: 1649717721623
# Finally traded at: 2022-04-12 00:55:22.334125
# ------------------------------------------
